# %%
import keras,os
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten
from keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
trdata = ImageDataGenerator()
traindata = trdata.flow_from_directory(directory=r "C:\Users\gayan\OneDrive\Documents\Deep_DataSet\Cat_and_dog\trainning_set",target_size=(224,224))
tsdata = ImageDataGenerator()
testdata = tsdata.flow_from_directory(directory=r "C:\Users\gayan\OneDrive\Documents\Deep_DataSet\Cat_and_dog\test_set", target_size=(224,224))

# %%
VGG = keras.applications.VGG16(input_shape=(224,224,3),include_top=False,weights='imagenet')
VGG.trainable =False

# %%
model =keras.sequantial([
    VGG,
    keras.layers.Flatten(),
    keras.layers.Dense(units=4096,activation="relu")
    keras.layers.Dense(units=4096,activation="relu")
    keras.layers.Dense(units=2, activation="softmax")
])

# %%
model.compile(optimizer='adam', loss=keras.losses.categorical_crossentropy,metrics=["accuracy"])

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model.summary()
#
# NameError: name 'model' is not defined

# %%
import keras
import os
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten
from keras.preprocessing.image import ImageDataGenerator
import numpy as np

trdata = ImageDataGenerator()
traindata = trdata.flow_from_directory(directory=r"C:\Users\gayan\OneDrive\Documents\Deep_DataSet\Cat_and_dog\trainning_set", target_size=(224,224))
tsdata = ImageDataGenerator()
testdata = tsdata.flow_from_directory(directory=r"C:\Users\gayan\OneDrive\Documents\Deep_DataSet\Cat_and_dog\test_set", target_size=(224,224))

VGG = keras.applications.VGG16(input_shape=(224,224,3), include_top=False, weights='imagenet')
VGG.trainable = False

model = Sequential([
    VGG,
    Flatten(),
    Dense(units=4096, activation="relu"),
    Dense(units=4096, activation="relu"),
    Dense(units=2, activation="softmax")
])

model.compile(optimizer='adam', loss=keras.losses.categorical_crossentropy, metrics=["accuracy"])
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\gayan\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Found 60 images belonging to 2 classes.
# Found 32 images belonging to 2 classes.
# WARNING:tensorflow:From C:\Users\gayan\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\gayan\anaconda3\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...
# 58889256/58889256 [==============================] - 12s 0us/step
# ...

# %%
# Assuming you've trained your model and stored the history
hist = model.fit(traindata, epochs=10, validation_data=testdata)

# Now you can visualize the training history
import matplotlib.pyplot as plt

plt.plot(hist.history["accuracy"])
plt.plot(hist.history["val_accuracy"])
plt.plot(hist.history["loss"])
plt.plot(hist.history["val_loss"])

plt.title("Model Accuracy and Loss")
plt.ylabel("Accuracy/Loss")
plt.xlabel("Epoch")
plt.legend(["Accuracy", "Validation Accuracy", "Loss", "Validation Loss"])
plt.show()
# Out:
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\gayan\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\gayan\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 2/2 [==============================] - 30s 18s/step - loss: 1836.7159 - accuracy: 0.3500 - val_loss: 329.0927 - val_accuracy: 0.3750
# Epoch 2/10
# 2/2 [==============================] - 27s 17s/step - loss: 139.1366 - accuracy: 0.6500 - val_loss: 2.9569 - val_accuracy: 0.9375
# Epoch 3/10
# 2/2 [==============================] - 26s 18s/step - loss: 7.9898 - accuracy: 0.8500 - val_loss: 12.2741 - val_accuracy: 0.7500
# Epoch 4/10
# ...

# %%
#we can show test with first input image - It is dog

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np

img = image.load_img(r"C:\Users\gayan\OneDrive\Documents\Deep_DataSet\Cat_and_dog\dog_or_cat1.jpg", target_size=(224,224))
img = np.asarray(img)
plt.imshow(img)
plt.show()

img = np.expand_dims(img, axis=0)

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np

img = image.load_img(r"C:\Users\gayan\OneDrive\Documents\Deep_DataSet\Cat_and_dog\dog_or_cat2.jpg", target_size=(224,224))
img = np.asarray(img)
plt.imshow(img)
plt.show()

img = np.expand_dims(img, axis=0)






from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np

img = image.load_img(r"C:\Users\gayan\OneDrive\Documents\Deep_DataSet\Cat_and_dog\dog_or_cat2.jpg", target_size=(224,224))
img = np.asarray(img)
plt.imshow(img)
plt.show()

img = np.expand_dims(img, axis=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 5
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
# ----> 5 img = image.load_img(r"C:\Users\gayan\OneDrive\Documents\Deep_DataSet\Cat_and_dog\dog_or_cat2.jpg", target_size=(224,224))
#       6 img = np.asarray(img)
#       7 plt.imshow(img)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\gayan\\OneDrive\\Documents\\Deep_DataSet\\Cat_and_dog\\dog_or_cat2.jpg'

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np

# Load and display the image dog_or_cat2.jpg
img_path = r"C:\Users\gayan\OneDrive\Documents\Deep_DataSet\Cat_and_dog\dog_or_cat2.jpg"
try:
    img = image.load_img(img_path, target_size=(224, 224))
    img = np.asarray(img)
    plt.imshow(img)
    plt.show()
    
    img = np.expand_dims(img, axis=0)
    
except FileNotFoundError:
    print(f"Error: File '{img_path}' not found.")
# Out:
# Error: File 'C:\Users\gayan\OneDrive\Documents\Deep_DataSet\Cat_and_dog\dog_or_cat2.jpg' not found.
